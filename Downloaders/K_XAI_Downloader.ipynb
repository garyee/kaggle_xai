# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
# !bash /content/drive/MyDrive/Colab/Kaggle/code/setup.sh
import sys
sys.path.append('/content/drive/MyDrive/Colab/Kaggle/code')
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
from kaggleDownloader import getAllKernelsForKaggleMostVotedEntity
from utils.kaggleEnums import KaggleEntityType

getAllKernelsForKaggleMostVotedEntity(KaggleEntityType.COMPETITION,1)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# competition: competitive-data-science-predict-future-sales 1
#   0%|          | 0/100 [00:00<?, ?it/s]
# competition: titanic 1
#   0%|          | 0/100 [00:00<?, ?it/s]
# competition: santander-customer-transaction-prediction 1
#   0%|          | 0/100 [00:00<?, ?it/s]
# competition: home-credit-default-risk 1
#   0%|          | 0/100 [00:00<?, ?it/s]
# competition: ieee-fraud-detection 1
#   0%|          | 0/100 [00:00<?, ?it/s]
# competition: m5-forecasting-accuracy 1
#   0%|          | 0/100 [00:00<?, ?it/s]
# competition: porto-seguro-safe-driver-prediction 1
#   0%|          | 0/100 [00:00<?, ?it/s]
# competition: santander-customer-satisfaction 1
#   0%|          | 0/100 [00:00<?, ?it/s]
# competition: amex-default-prediction 1
#   0%|          | 0/100 [00:00<?, ?it/s]
# competition: jigsaw-toxic-comment-classification-challenge 1
#   0%|          | 0/100 [00:00<?, ?it/s]
# competition: LANL-Earthquake-Prediction 1
# ...
